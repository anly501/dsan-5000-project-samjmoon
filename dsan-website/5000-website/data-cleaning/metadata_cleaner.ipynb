# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import os
os.chdir('/Users/samanthamoon/Desktop/DSAN 5000/dsan-5000-project-samjmoon/dsan-website/5000-website/data-cleaning')

metadata_df = pd.read_csv('movies_metadata.csv')
metadata_df['genres'] = metadata_df['genres'].apply(lambda x: [genre['name'] for genre in literal_eval(x)] if isinstance(x, str) else [])
metadata_df.head()
# Out:
# /var/folders/mm/79b3ggcn52x9kcrnqfx5mtk40000gn/T/ipykernel_3332/897346492.py:7: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata_df = pd.read_csv('movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# ...

# %%
num_columns = metadata_df.shape[1]
num_columns
column_names = metadata_df.columns.tolist()
print("Column names:", column_names)
num_rows = metadata_df.shape[0]
num_rows
# Out:
# Column names: ['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count']
# 45466

# %%
columns_to_drop = ['adult','belongs_to_collection','homepage', 'overview', 'poster_path', 'tagline', 'video', 'status', 'production_countries', 'original_language', 'spoken_languages', 'production_companies']
metadata_df = metadata_df.drop(columns=columns_to_drop, axis=1)
metadata_df.head()
metadata_df = metadata_df.rename(columns={'id': 'tmdbId'})
metadata_df['tmdbId'] = pd.to_numeric(metadata_df['tmdbId'], errors='coerce')
metadata_df['tmdbId'] = metadata_df['tmdbId'].astype(float)
#Check if any column in the DataFrame contains NaN values
any_nan_values = metadata_df.isna().any()

#Display which columns have NaN values
print(any_nan_values)
# Out:
# budget            False
# genres            False
# tmdbId             True
# imdb_id            True
# original_title    False
# popularity         True
# release_date       True
# revenue            True
# runtime            True
# title              True
# vote_average       True
# vote_count         True
# dtype: bool

# %%
metadata_df = metadata_df.dropna(subset=['tmdbId', 'imdb_id', 'vote_average', 'vote_count', 'runtime'])
num_rows = metadata_df.shape[0]
num_rows
any_nan_values = metadata_df.isna().any()

# Display which columns have NaN values
print(any_nan_values)
metadata_df.head()
# Out:
# budget            False
# genres            False
# tmdbId            False
# imdb_id           False
# original_title    False
# popularity        False
# release_date       True
# revenue           False
# runtime           False
# title             False
# vote_average      False
# vote_count        False
# dtype: bool
#      budget                        genres   tmdbId    imdb_id  \
# 0  30000000   [Animation, Comedy, Family]    862.0  tt0114709
# 1  65000000  [Adventure, Fantasy, Family]   8844.0  tt0113497
# 2         0             [Romance, Comedy]  15602.0  tt0113228
# 3  16000000      [Comedy, Drama, Romance]  31357.0  tt0114885
# 4         0                      [Comedy]  11862.0  tt0113041
#
#                 original_title popularity release_date      revenue  runtime  \
# 0                    Toy Story  21.946943   1995-10-30  373554033.0     81.0
# 1                      Jumanji  17.015539   1995-12-15  262797249.0    104.0
# ...

# %%
file_path = './cleaned_metadata_movies.csv' 
metadata_df.to_csv(file_path, index=False)
